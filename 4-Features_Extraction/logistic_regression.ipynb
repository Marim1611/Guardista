# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('graphs_representations.csv')
data.head()
# Out:
#             X0           X1           X2           X3          X4  \
# 0    39.501122   116.428207   673.427124  1963.811401  752.812439
# 1     9.102110  1603.886230   191.628326   119.186852  182.162994
# 2    15.690063   111.384933    21.260721   697.769958   44.845589
# 3    14.647839   187.728119  1314.511353   354.322205  668.759277
# 4  1203.722900    66.260345    39.026497    24.890083   11.337747
#
#             X5           X6           X7          X8          X9  ...  \
# 0  1585.693970    11.756994   664.576172    0.000000   23.858341  ...
# 1  1490.487183   642.083679   404.016388    2.494440    1.233383  ...
# 2     1.140956   201.672104   171.572098  914.394287    0.000000  ...
# 3    62.661407   153.568558    55.726795  738.709717  977.511658  ...
# 4    22.371778  2494.580322  1610.011108   19.564665    0.000000  ...
#
#          X119         X120        X121         X122        X123         X124  \
# 0  149.650436     4.083194  135.929565   804.790283   56.065708     0.166509
# 1   50.445923    45.076077    0.068493    30.462379   91.927559   889.395508
# 2    9.193646    17.182955   30.581701   217.942764  141.434113    38.787682
# 3   57.749256  1470.470459   94.329178    57.078747   36.822807     1.607852
# 4   45.026295  1577.091431   24.333614  1314.204834  275.696075  1347.827393
#
#           X125         X126         X127      y
# 0  1016.657837    76.455299     6.116460  cve23
# 1  1095.218994   470.761353   164.920807  cve23
# 2    79.371902   795.254211    53.887665  cve23
# 3   415.523438  2116.668457  1640.181763  cve23
# 4     1.017371     2.862271   103.140526  cve23
#
# [5 rows x 129 columns]

# %%
data.tail()
# Out:
#               X0           X1          X2          X3           X4  \
# 1849   24.946749   375.393921  223.598297   15.505322   201.668365
# 1850    1.031244    11.086925   41.299095  799.339233  1452.015381
# 1851  850.975342  1142.271362  381.524902  221.067169    23.380091
# 1852    0.156271    54.731529    0.452811   37.991482    13.856159
# 1853   11.298733     7.109472    4.920832   12.847380  1322.782471
#
#                X5          X6           X7           X8           X9  ...  \
# 1849  1243.309692  287.765869    47.902645   417.151276  1790.263428  ...
# 1850   636.140320    3.208474   175.456924   187.643814   146.394791  ...
# 1851   974.624634  861.603943  1723.572144     1.763937  1152.458862  ...
# 1852    33.889477    3.534220    18.626610    15.768745     9.559669  ...
# 1853    66.743050  118.977036    70.364998  1106.536499   968.069031  ...
#
#              X119        X120        X121        X122        X123        X124  \
# 1849    23.404358  119.273048  246.253052  903.793152  465.285858  322.406982
# 1850   181.513840   18.301065   10.817625   70.626480    1.888877    3.513565
# 1851  1034.629639  579.828430   61.268291    0.957901  716.587463    3.722681
# 1852     1.415125   64.189644    2.052948    0.204440   12.234146    9.032621
# 1853   292.737549   75.189857  363.571503  109.382080   85.890778  331.074188
#
#             X125        X126         X127     y
# 1849  503.925964    0.556459    43.134861  safe
# 1850  854.793640  897.473206    75.678406  safe
# 1851  346.912323  263.732574  1914.982788  safe
# 1852   65.272469    0.004676     6.094564  safe
# 1853  281.706573  587.527283    12.767244  safe
#
# [5 rows x 129 columns]

# %%
def X_y_split(df):
    df_numpy = df.to_numpy()
    features = df_numpy[:, :-1]
    labels = df_numpy[:, -1]
    # or without converting to numpy
    # X = df.iloc[:, :-1]
    # y = df.iloc[:, -1]
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=0)
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = X_y_split(data)
X_train, X_test, y_train, y_test
# Out:
# (array([[226.47769165039065, 1633.652587890625, 6.611439228057861, ...,
#          788.6874389648438, 49.40897750854492, 264.9848327636719],
#         [1324.1993408203125, 1612.79296875, 21.645118713378903, ...,
#          77.53382110595703, 57.41183090209961, 713.751953125],
#         [15.935415267944336, 1087.4827880859375, 67.17807006835938, ...,
#          1125.46044921875, 30.64189338684082, 9.18263339996338],
#         ...,
#         [178.3601531982422, 736.654541015625, 9.17966651916504, ...,
#          1777.9832763671875, 31.686960220336918, 48.961334228515625],
#         [112.5445785522461, 1276.6771240234375, 1206.1773681640625, ...,
#          0.0, 733.7501220703125, 1246.70947265625],
#         [66.65160369873047, 671.3534545898438, 431.6401672363281, ...,
#          1684.07666015625, 911.8856201171876, 48.516380310058594]],
#        dtype=object),
#  array([[241.59246826171875, 385.1634826660156, 1218.5675048828125, ...,
#          647.693115234375, 1770.2962646484375, 667.7374267578125],
#         [585.00146484375, 270.3994445800781, 945.2572631835938, ...,
#          55.146629333496094, 303.5495300292969, 1631.6976318359375],
#         [1724.51806640625, 414.7157897949219, 19.762603759765625, ...,
#          1036.9547119140625, 1484.4195556640625, 2338.833984375],
#         ...,
#         [1409.2720947265625, 433.99896240234375, 404.2310180664063, ...,
#          500.00335693359375, 339.6883850097656, 3.912854194641113],
#         [74.28941345214844, 699.2738037109375, 803.1818237304688, ...,
#          180.9239959716797, 87.29195404052734, 21.61823844909668],
#         [122.20449829101562, 77.08705139160156, 721.204833984375, ...,
#          51.652679443359375, 575.3826904296875, 145.55429077148438]],
#        dtype=object),
#  array(['cve23', 'cve23', 'cve23', ..., 'safe', 'cve23', 'cve23'],
#        dtype=object),
#  array(['cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'safe', 'safe', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23', 'cve23',
#         'cve23', 'safe', 'cve23', 'safe', 'cve23', 'cve23', 'cve23',
#         'safe', 'cve23', 'safe', 'cve23', 'cve23', 'cve23', 'safe',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'safe', 'cve23',
#         'safe', 'cve23', 'cve23', 'safe', 'cve23', 'cve23', 'safe', 'safe',
#         'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'safe',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'safe', 'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23',
#         'cve23', 'cve23', 'safe', 'cve23', 'safe', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'safe', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'safe', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23',
#         'safe', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe',
#         'safe', 'cve23', 'safe', 'cve23', 'cve23', 'cve23', 'safe',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'safe', 'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23', 'safe',
#         'safe', 'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23',
#         'cve23', 'safe', 'cve23', 'cve23', 'cve23', 'cve23', 'safe',
#         'cve23', 'safe', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23',
#         'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23', 'safe',
#         'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23', 'cve23',
#         'safe', 'cve23', 'safe', 'cve23', 'safe', 'cve23', 'cve23', 'safe',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'safe', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe',
#         'cve23', 'cve23', 'safe', 'cve23', 'cve23', 'safe', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'safe', 'cve23',
#         'safe', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23', 'cve23',
#         'cve23', 'cve23', 'safe', 'safe', 'cve23', 'cve23', 'cve23',
#         'cve23', 'safe', 'cve23', 'cve23', 'safe'], dtype=object))

# %%
# %%time
# We use time to compute the training time of our model
model = LogisticRegression(random_state=0, penalty="none").fit(X_train, y_train)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 58.9 ms
# c:\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(

# %%
y_train_predict = model.predict(X_train)
print(f"Training Accurracy: {accuracy_score(y_train, y_train_predict) * 100}%")
y_test_predict = model.predict(X_test)
print(f"Testing Accurracy: {accuracy_score(y_test, y_test_predict) * 100}%")
# Out:
# Training Accurracy: 80.3776129467296%
# Testing Accurracy: 81.13207547169812%
