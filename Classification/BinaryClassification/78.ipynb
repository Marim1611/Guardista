# %%
import sys; sys.path.append('../')
from DataPreparing.data_preparing import *
from Evaluation.evaluate import *
from sklearn import svm
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from imblearn.under_sampling import NearMiss,RandomUnderSampler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %%
#read csv file without header and index into dataframe
df1=  pd.read_csv('../DataFiles/gcn_new_embeddings/concatEmbeddings_78.csv', header=None, index_col=None)
df2 =  pd.read_csv('../DataFiles/gcn_new_embeddings/concatEmbeddings_78_safe.csv', header=None, index_col=None)
# df3 = pd.read_csv('../DataFiles/gcn_embeddings/all/embeddings_group3.csv', header=None, index_col=None)
# df4 = pd.read_csv('../DataFiles/gcn_embeddings/all/embeddings_group4.csv', header=None, index_col=None)

# %%
#combine all dataframes into one
df = pd.concat([df1, df2], ignore_index=True)

# %%
#write dataframe into csv file
df.to_csv('../DataFiles/gcn_new_embeddings/78_concat.csv', index=False, header=False)

# %%
#drop first column
df = df.drop(df.columns[0], axis=1)

# %%
df_numpy = df.to_numpy()
features = df_numpy[:, :-1]
labels = df_numpy[:, -1]
X_train, X_val, y_train, y_val = train_test_split(features, labels, test_size=0.2, random_state=0)

# %%
print(y_val[0])
# Out:
# CWE78_safe

# %%
print(set(y_train))
# Out:
# {'CWE78', 'CWE78_safe'}

# %%
# %%time
clf = svm.SVC( kernel='rbf')
clf.fit(X_train, y_train)
evaluate(clf, X_val,y_val , clf.predict(X_train), y_train)
# Out:
# Training Accurracy: 63.48892032060349%
#               precision    recall  f1-score   support
#
#        CWE78       0.68      0.50      0.58      1252
#   CWE78_safe       0.64      0.79      0.71      1400
#
#     accuracy                           0.65      2652
#    macro avg       0.66      0.65      0.64      2652
# weighted avg       0.66      0.65      0.65      2652
#
# CPU times: total: 1min 28s
# Wall time: 1min 33s

# %%
save_model(clf, "78_concat_rbf")

# %%
from scipy.stats import loguniform

c_range =loguniform(1e-5, 1e5)
gamma_range = np.linspace(0.0001, 1)
#kernels= ['linear' ,'rbf']
param_grid = {'C': c_range,
              'gamma': gamma_range,
               #'kernel' : kernels
             }

# %%
parameter_search(X_train, y_train, clf, param_grid)

# %% [markdown]
# ## Adaboost

# %%
# %%time
clf = AdaBoostClassifier(n_estimators=50)
clf.fit(X_train, y_train)
evaluate(clf, X_val,y_val, clf.predict(X_train), y_train)
# Out:
# Training Accurracy: 100.0%
#               precision    recall  f1-score   support
#
#        CWE78       1.00      1.00      1.00      1252
#   CWE78_safe       1.00      1.00      1.00      1400
#
#     accuracy                           1.00      2652
#    macro avg       1.00      1.00      1.00      2652
# weighted avg       1.00      1.00      1.00      2652
#
# CPU times: total: 1min 24s
# Wall time: 1min 32s

# %%
# %%time
clf = svm.SVC( kernel='rbf')
clf.fit(X_train, y_train)
evaluate(clf, X_val,y_val , clf.predict(X_train), y_train)
# Out:
# Training Accurracy: 63.48892032060349%
#               precision    recall  f1-score   support
#
#        CWE78       0.68      0.50      0.58      1252
#   CWE78_safe       0.64      0.79      0.71      1400
#
#     accuracy                           0.65      2652
#    macro avg       0.66      0.65      0.64      2652
# weighted avg       0.66      0.65      0.65      2652
#
# CPU times: total: 1min 24s
# Wall time: 1min 27s

# %% [markdown]
# ## Logistic Regression

# %%
clf=LogisticRegression(random_state=0, penalty="none")
clf.fit(X_train, y_train)
evaluate(clf, X_val,y_val, clf.predict(X_train), y_train)
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training Accurracy: 95.72842998585573%
#               precision    recall  f1-score   support
#
#        CWE78       0.95      0.97      0.96      1252
# ...

# %%
df=  pd.read_csv('../DataFiles/gcn_new_embeddings/embeddings_concat.csv', header=None, index_col=None)
test_point = df.to_numpy()

# %%
new_lr=LogisticRegression(random_state=0, penalty="none")
new_lr.fit(X_train, y_train)
evaluate(new_lr, X_val,y_val, new_lr.predict(X_train), y_train)
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training Accurracy: 95.72842998585573%
#               precision    recall  f1-score   support
#
#        CWE78       0.95      0.97      0.96      1252
# ...

# %%
#select the first 128 point in the feature from reach point in x_train
X_train_128 = X_train[:, -1:]
X_val_128 = X_val[:, -1:]
print(X_train_128.shape)
neww_lr=LogisticRegression(random_state=0, penalty="none")
neww_lr.fit(X_train_128, y_train)
evaluate(neww_lr, X_val_128,y_val, neww_lr.predict(X_train_128), y_train)
# Out:
# (10605, 1)
# Training Accurracy: 97.001414427157%
#               precision    recall  f1-score   support
#
#        CWE78       0.95      0.99      0.97      1252
#   CWE78_safe       0.99      0.95      0.97      1400
#
#     accuracy                           0.97      2652
#    macro avg       0.97      0.97      0.97      2652
# weighted avg       0.97      0.97      0.97      2652
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(

# %%
print(lr.predict(test_point))
print(len(test_point[0]))
# Out:
# ['CWE78']
# 256

# %%
import umap

# Create a UMAP object with 2 dimensions

umap_obj = umap.UMAP(n_components=2, n_neighbors=10, min_dist=0.1, metric='euclidean')

# Fit the UMAP object to the data and transform it into a 2D space
X_umap = umap_obj.fit_transform(test_point)

# Plot the 2D representation of the data
plt.scatter(X_umap[:, 0], X_umap[:, 1], s=5, alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import umap
#       3 # Create a UMAP object with 2 dimensions
#       5 umap_obj = umap.UMAP(n_components=2, n_neighbors=10, min_dist=0.1, metric='euclidean')
#
# ModuleNotFoundError: No module named 'umap'

# %%
from sklearn.feature_selection import RFEوRFECV

# Create a recursive feature elimination object with the linear regression estimator
# rfe = RFECV(lr, cv=KFold(10), scoring='neg_mean_squared_error')
rfe = RFECV(lr, cv=KFold(10), scoring='neg_mean_squared_error')

# Fit the RFE object to the data
rfe.fit(X_train, y_train)

# Print the features ranked by their importance score
print("Feature ranking:", rfe.ranking_)

# Print the selected features
print("Selected features:",rfe.support_)
# select the chosen features from X_train
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
X_train_selected = X_train[:,rfe.support_]
X_val_selected = X_val[:,rfe.support_]

# %%
# %%time
clf = svm.SVC( kernel='rbf')
clf.fit(X_train_selected, y_train)
evaluate(clf, X_val_selected,y_val , clf.predict(X_train_selected), y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:3
#
# File e:\GP\Guardista\Classification\Evaluation\evaluate.py:5, in evaluate(clf, X_val, y_val, y_train_predict, y_train)
#       4 def evaluate(clf, X_val,y_val, y_train_predict, y_train):
# ----> 5     y_pred =clf.predict(X_val)
#       6     print(f"Training Accurracy: {accuracy_score(y_train, y_train_predict) * 100}%")
#       7     print(classification_report(y_val, y_pred))
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\svm\_base.py:820, in BaseSVC.predict(self, X)
#     818     y = np.argmax(self.decision_function(X), axis=1)
#     819 else:
# --> 820     y = super().predict(X)
#     821 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\svm\_base.py:433, in BaseLibSVM.predict(self, X)
# ...

# %%
evaluate(clf, X_val_selected,y_val , clf.predict(X_train_selected), y_train)
# Out:
# Training Accurracy: 63.31918906176332%
#               precision    recall  f1-score   support
#
#        CWE78       0.68      0.50      0.58      1252
#   CWE78_safe       0.64      0.79      0.70      1400
#
#     accuracy                           0.65      2652
#    macro avg       0.66      0.64      0.64      2652
# weighted avg       0.66      0.65      0.64      2652

# %%
# %%time
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train_selected, y_train)
evaluate(clf, X_val_selected,y_val, clf.predict(X_train_selected), y_train)
# Out:
# Training Accurracy: 100.0%
#               precision    recall  f1-score   support
#
#        CWE78       1.00      1.00      1.00      1252
#   CWE78_safe       1.00      1.00      1.00      1400
#
#     accuracy                           1.00      2652
#    macro avg       1.00      1.00      1.00      2652
# weighted avg       1.00      1.00      1.00      2652
#
# CPU times: total: 3.92 s
# Wall time: 4.89 s

# %%
print(clf.predict(test_point[:,rfe.support_]))
# Out:
# ['CWE78']

# %%
clf=LogisticRegression(random_state=0, penalty="none")
clf.fit(X_train_selected, y_train)
evaluate(clf, X_val_selected,y_val, clf.predict(X_train_selected), y_train)
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training Accurracy: 93.32390381895333%
#               precision    recall  f1-score   support
#
#        CWE78       0.89      0.97      0.93      1252
# ...
