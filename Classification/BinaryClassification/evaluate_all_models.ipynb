# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys; sys.path.append('../')
from DataPreparing.data_preparing import *
from DataPreparing.HandleClassImbalance import *
from Evaluation.evaluate import *

# %% [markdown]
# # Testing Binary classifier
#     - This notebook to test all binary classifier on 100 random sample file
#       from each CVE class

# %% [markdown]
# ## load test random samples

# %%
dir_path='../DataFiles/binary/vuln'

# %%
X_all,y_all= get_data(dir_path)

# %% [markdown]
# ## Load and View Results

# %%
model=load_model('ADB_122.pkl')

# %%
test_all_binary(X_all,y_all,model,'CWE122')

# %%
model=load_model('LR_191.pkl')

# %%
model=load_model('LR_134.pkl')

# %%
test_all_binary(X_all,y_all,model,'CWE134')

# %%
model=load_model('ADB_457.pkl')
test_all_binary(X_all,y_all,model,'CWE457')

# %%
test_all_binary(X_all,y_all,model,'CWE127')

# %%
model=load_model('ADB_126.pkl')

# %%
test_all_binary(X_all,y_all,model,'CWE126')

# %%
model=load_model('ADB_127.pkl')

# %%
model=load_model('LR_690.pkl')
test_all_binary(X_all,y_all,model,'CWE690')

# %%
test_all_binary(X_all,y_all,model,'CWE191')
